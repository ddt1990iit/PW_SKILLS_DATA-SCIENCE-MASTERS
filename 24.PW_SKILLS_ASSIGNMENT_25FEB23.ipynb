# %% [markdown]
# # ASSIGNMENT_25thFEB_2023_PWSKIILLS

# %% [markdown]
# ## Consider following code to answer further questions:
# ### import pandas as pd
# ### course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
# ### duration = [2,3,6,4]
# ### df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ : duration})
#
# ## Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
display(df.iloc[1:2]) # Code used to display the second row of the data frame
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# ## Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [markdown]
# The **loc()** function is label based data selecting method which means that we have to pass the name of the row or column which we want to select. This method includes the last element of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc().

# %% [markdown]
# The **iloc()** function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it unlike loc(). iloc() does not accept the boolean data unlike loc()

# %% [markdown]
# ## Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].
#
# ## Did you observe any difference in both the outputs? If so then explain it.

# %%
reindex = [3,0,1,2]

new_df = df.reindex(reindex)

display(new_df)
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
# Output of new_df.loc[2]

display(new_df.loc[2])

"Explanation :  loc() function return the row after reading the index assigned to the particular row"
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
# 'Explanation :  loc() function return the row after reading the index assigned to the particular row'

# %%
# Output of new_df.iloc[2]

display(new_df.iloc[2])

"""Explanation : iloc() function return the row with actual indexing done in pandas library using the convention used in python. 
Index based return."""
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object
# 'Explanation : iloc() function return the row with actual indexing done in pandas library using the convention used in python. \nIndex based return.'

# %% [markdown]
# ## Consider the below code to answer further questions:
# ### import pandas as pd
# ### import numpy as np
# ### columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
# ### indices = [1,2,3,4,5,6]
# ### Creating a dataframe:
# ### df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %% [markdown]
# ## Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# ### (i) mean of each and every column present in the dataframe.
# ### (ii) standard deviation of column, ‘column_2’

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
display(df1)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.979084  0.234482  0.749663  0.336525  0.610092  0.382449
# 2  0.547352  0.712356  0.857330  0.175681  0.270438  0.171502
# 3  0.729767  0.215871  0.429453  0.725702  0.631007  0.990212
# 4  0.361477  0.538444  0.261508  0.015624  0.400354  0.652102
# 5  0.918974  0.914623  0.225807  0.971302  0.397274  0.564460
# 6  0.785823  0.276180  0.942364  0.198537  0.531234  0.799246

# %%
"(i) mean of each and every column present in the dataframe."

df1.describe().iloc[1:2]
# Out:
#       column_1  column_2  column_3  column_4  column_5  column_6
# mean  0.720413  0.481993  0.577688  0.403895    0.4734  0.593328

# %%
"(ii) standard deviation of column, ‘column_2’"

df1.describe().iloc[2:3,[1]]
# Out:
#      column_2
# std   0.28909

# %% [markdown]
# ## Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.
# ### If you are getting errors in executing it then explain why.
# #### [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
# Replacing the data present in second row of Column_2 by string variable

df1.iloc[1:2,[1]] = 'Dharmendra'

df1
# Out:
#    column_1    column_2  column_3  column_4  column_5  column_6
# 1  0.979084    0.234482  0.749663  0.336525  0.610092  0.382449
# 2  0.547352  Dharmendra  0.857330  0.175681  0.270438  0.171502
# 3  0.729767    0.215871  0.429453  0.725702  0.631007  0.990212
# 4  0.361477    0.538444  0.261508  0.015624  0.400354  0.652102
# 5  0.918974    0.914623  0.225807  0.971302  0.397274  0.564460
# 6  0.785823     0.27618  0.942364  0.198537  0.531234  0.799246

# %%
"""Explanation : The below code will throw an Exception of subclass Type_error. Float and string cvalue cannot be used for 
   mathematical calculations"""

try:
    df1['column_2'].mean()
except Exception as e:
    print(e,e.__class__)
# Out:
# unsupported operand type(s) for +: 'float' and 'str' <class 'TypeError'>

# %% [markdown]
# ## Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [markdown]
# **The window functions** in Pandas are used to perform some sort of calculations across a set of rows that are interrelated with the current row. As we know we have aggregate functions in SQL which help us to perform mathematical calculations among the columns of a table, similarly windows functions help us to perform aggregated calculations across various partitions or cross-sections of the data.
#
# There is a major difference between the standard aggregate function of SQL and windows functions in Pandas, the aggregate function of SQL returns us a single value after performing the calculation specified in the SQL query. On the other hand, the windows function in Pandas, returns a value for every row of the original table.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python Window Functions Overview Diagram :
#
# ### Types of windows functions:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q7. Write a code to print only the current month and year at the time of answering this question.
# #### [Hint: Use pandas.datetime function]

# %%
import pandas as pd

current_time = pd.datetime.now()

display(current_time)

month = current_time.month

year = current_time.year

print('The month od the current time is : ',month)

print('The Year of the current time is :', year)
# Out:
# <ipython-input-125-74533450196c>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   current_time = pd.datetime.now()
# datetime.datetime(2023, 3, 13, 13, 28, 21, 865317)
# The month od the current time is :  3
# The Year of the current time is : 2023

# %% [markdown]
# ## Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.

# %%
import pandas as pd

# Input the date from the user

date1 = input('Enter the date as input (in the format YYYY-MM-DD) ')
date2 = input('Enter the date as input (in the format YYYY-MM-DD) ')

# Convert the string date to date time format
try:
    
    date_1 = pd.to_datetime(date1)
    date_2 = pd.to_datetime(date2)


# Calculating the differnece between two dates 

    diff = date_2 - date_1

# Extracting the days info from the differnce

    diff_days = diff.days

    print(f'The difference between the two dates is : {diff_days}')

except Exception as e:
    print(e,e.__class__)
# Out:
# Enter the date as input (in the format YYYY-MM-DD) 2023-03-13
# Enter the date as input (in the format YYYY-MM-DD) 2024-03-13
# The difference between the two dates is : 366

# %% [markdown]
# ## Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.

# %% [markdown]
# https://github.com/ddt1990iit/PW_SKILLS_DATA-SCIENCE-MASTERS/blob/main/Air_Traffic_Passenger_Statistics.csv

# %%
import pandas as pd

# Path input by user 

print('=================================================================================\n')

file_path = input('Enter the path to read csv file: ')

print('=================================================================================\n')
print(df.columns[1:11])  # To display the comumn name to user

# Coulmn name user want to convert the data into categorical data 

print('=================================================================================\n')

column_name = input('Choose from column mentioned above ')

df = pd.read_csv(file_path) 

print('=================================================================================\n')

category_order = input('Enter the category order either ascending of descending').lower()

# Converting the column into categorical data type 

category = df[column_name].unique()

df[column_name] = pd.Categorical(df[column_name],categories= category)

# Sorting the dataframe in user category order

if category_order == 'ascending':
    print('=================================================================================')

    df_sorted = df.sort_values(column_name, ascending=True)
    display(df_sorted)

else:
    print('=================================================================================')
    
    df_sorted = df.sort_values(column_name, ascending=False)
    display(df_sorted)
# Out:
# ...
#
# Enter the path to read csv file: Air_Traffic_Passenger_Statistics.csv
# ...
#
# Index(['Operating Airline', 'Operating Airline IATA Code', 'Published Airline',
#        'Published Airline IATA Code', 'GEO Summary', 'GEO Region',
#        'Activity Type Code', 'Price Category Code', 'Terminal',
#        'Boarding Area'],
#       dtype='object')
# ...
#
# Choose from column mentioned above Operating Airline
# ...
#
# Enter the category order either ascending of descendingascending
# ...
#     Activity Period Operating Airline Operating Airline IATA Code  \
# 0            200507      ATA Airlines                          TZ
# 1            200507      ATA Airlines                          TZ
# 2            200507      ATA Airlines                          TZ
# 3            200507        Air Canada                          AC
# 4            200507        Air Canada                          AC
# 5            200507         Air China                          CA
# ...

# %% [markdown]
# ## Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.

# %% [markdown]
# https://github.com/ddt1990iit/PW_SKILLS_DATA-SCIENCE-MASTERS/blob/main/sales_data_sample.csv

# %%
import pandas as pd

# Taking path as input from the user
print('=================================================================================\n')

file_path = input('Enter the path of the dataset')

df = pd.read_csv(file_path)

# Asking for the first query from the user to see the dataset

print('=================================================================================\n')

query1 = input('Do you want to see the data Frame').lower()

if query1 == 'yes':
    
    print('=================================================================================\n')
    display(df)

else:
    pass

# Asking for the second query to visualize the data 

query2 = input('Do you want to see the visulization of Sales data over Year??').lower()

if query2 == 'yes':
    print('=================================================================================\n')
    # Visualizing Sales with Product Category using Bar Plot

    import seaborn as sns
    import matplotlib.pyplot as plt


    plt.figure(figsize=(15,10))
    plt.title('SALES OF PRODUCT WITH YEAR')

    sns.barplot(df['YEAR_ID'],df['SALES'],hue=df['PRODUCTLINE'])
else:
    print('=================================================================================\n')
    print('THANK YOU!!!!')
# Out:
# ...
#
# Enter the path of the datasetsales_data_sample.csv
# ...
#
# Do you want to see the data Frameyes
# ...
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
# ...

# %% [markdown]
# ### Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.
# ### The program should do the following
# ### I Prompt the user to enter the file path of the CSV file containing the student dataR
# ### I Read the CSV file into a Pandas DataFrameR
# ### I Calculate the mean, median, and mode of the test scores using Pandas toolsR
# ### I Display the mean, median, and mode in a table.
# ### Assume the CSV file contains the following columnsM
# ### I Student ID: The ID of the studentR
# ### I Test Score: The score of the student's test.
#
# ![image.png](attachment:image.png)

# %%
# Input the data to data frame from the given entry

data = {'Student_Id' : [i for i in range(1,11)],
       'Test Score' : [ 85,90,80,75,85,82,78,85,90,85]}

df = pd.DataFrame(data)

# Saving the data to csv file 

df.to_csv('student_data.csv',index=False)

path_id = input('Enter the path of the dataset')

df1 = pd.read_csv(path_id)

print("Data Frame : ")

display(df1)

# Calculating the Statistics

mean = df['Test Score'].mean()
mode = df['Test Score'].mode()[0]
median = df['Test Score'].median()

# Displaying the statistics in Tabular Format

df_statistics = pd.DataFrame({'Staistics' : ['Mean','Median','mode'],
                'Values' : [mean,median,mode]})


display(df_statistics)
# Out:
# Enter the path of the datasetstudent_data.csv
# Data Frame :
#    Student_Id  Test Score
# 0           1          85
# 1           2          90
# 2           3          80
# 3           4          75
# 4           5          85
# 5           6          82
# 6           7          78
# 7           8          85
# 8           9          90
# 9          10          85
#   Staistics  Values
# 0      Mean    83.5
# 1    Median    85.0
# 2      mode    85.0
