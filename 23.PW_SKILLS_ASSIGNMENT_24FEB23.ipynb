# %% [markdown]
# # ASSIGNMENT_24thFEB_2023_PWSKIILLS

# %% [markdown]
# ## Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# **Read()**
#
# We can read data in pandas data frame as read_csv(). Two most used data read formats are csv and excel. If we are reading data in excel format, we can also give sheet names as follows. There are other less used options of other file types too.

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# **Head() and Tail()**
#
# To see the data frame we can use df.head(). Head returns the first rows, if no input is given it will always show above 5 rows. In contrast to see below rows, we can use df.tail().

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN

# %% [markdown]
# **Shape(), Size() and Info()**
#
# Two most basic functions after reading data is to know the number of rows and columns, and to know the datatype of variables. We can use df.shape, it gives a total number of rows and then columns. df.size() returns the number of rows times number of columns in the data frame. We can also use df.info(), from that we get different information such as rows from RangeIndex, Data columns and then data type of each column. It also includes the information of non-null counts.

# %%
df.shape
# Out:
# (1310, 14)

# %%
df.size
# Out:
# 18340

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# **isna()**
#
# if one needs to get the total number of null values in a data, we can use df.isna() as below. Sum will give the total null values. If we want just one variable null values, we can also get it by giving the name of the variable as below.

# %%
df.isna().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %% [markdown]
# **Describe()**
#
# To understand basic statistics of variables we can use df.describe(). It will give you count, mean, standard deviation, and also 5 number summary.

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ## Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data = {'A' : ['DD','Ankit','Harihar'],
       'B':['Data Science','Java','Web Dev'],
       'C':['Sudh','Krish','Naveen']}

# Creating a data Frame

df = pd.DataFrame(data)

df
# Out:
#          A             B       C
# 0       DD  Data Science    Sudh
# 1    Ankit          Java   Krish
# 2  Harihar       Web Dev  Naveen

# %%
# Reindexing

new_index = [i for i in range(1,6,2)] # Giving the new index value from 1 to 5 with step of 2

df.reindex(new_index,fill_value='missing Value')
# Out:
#                A              B              C
# 1          Ankit           Java          Krish
# 3  missing Value  missing Value  missing Value
# 5  missing Value  missing Value  missing Value

# %% [markdown]
# ### Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console. For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
import pandas as pd

df = pd.DataFrame({'values':[10,20,30,40,50]})

def sum_values(df):
    sum = df['values'][0:3].sum()  # Slicing the first three values of df column
    return sum
    
sum = sum_values(df)

print('The data Frame is\n',df)

print(f'The sum of the first three value of the column of Data Frame is :  {sum}' )
# Out:
# The data Frame is
#     values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# The sum of the first three value of the column of Data Frame is :  60

# %% [markdown]
# ### Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame({'Text':['I love Data science masters','web development is good course to learn','pwskills is great platform to learn data science']})

# Function to calculate the the number of words in a string

def Word_Count(df):
    for i in range(0,df.size):
        df['Word_count'] = df['Text'].apply(lambda x: len(x.split()))
    return df


df_updated = Word_Count(df)

df_updated
# Out:
#                                                Text  Word_count
# 0                       I love Data science masters           5
# 1           web development is good course to learn           7
# 2  pwskills is great platform to learn data science           8

# %% [markdown]
# ## Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# ## Pandas .size, .shape are used to return size, shape of data frames and series.
#
# ### Syntax: dataframe.size
# Return : Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
#
# ### Syntax: dataframe.shape
# Return : Returns tuple of shape (Rows, columns) of dataframe/series

# %% [markdown]
# ## Q6. Which function of pandas do we use to read an excel file

# %% [markdown]
# We can use the pandas module read_excel() function to read the excel file data into a DataFrame object. This function is part of the Pandas IO tools and can read data from Excel files with various extensions like .xlsx, .xls, and .xlsm.

# %% [markdown]
# ## Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
#
# ## The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
df = pd.DataFrame({'Email':['dharmendra.dubey@gmail.com','ankit.srivastava@gmail.com','sudhanshu@gmail.com']})


def username(df):
    for i in range(0,df.size):
        df['Username'] = df['Email'].apply(lambda x: x.split('@')[0]) # Lambda function to extract the username using split function
    return df

df_updated = username(df)

df_updated
# Out:
#                         Email          Username
# 0  dharmendra.dubey@gmail.com  dharmendra.dubey
# 1  ankit.srivastava@gmail.com  ankit.srivastava
# 2         sudhanshu@gmail.com         sudhanshu

# %% [markdown]
# ## Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10.
# ## The function should return a new DataFrame that contains only the selected rows.
# ## For example, if df contains the following values:
# ### A B C
# ### 0 3 5 1
# ### 1 8 2 7
# ### 2 6 9 4
# ### 3 2 3 5
# ### 4 9 1 2
#
# ### Assignment
#
# ## Data Science Masters
#
# ### Your function should select the following rows: A B C
# ### 1 8 2 7
# ### 4 9 1 2
# ### The function should return a new DataFrame that contains only the selected rows.

# %%
df = pd.DataFrame({'A':[3,8,6,2,9],
                   'B':[5,2,9,3,1],
                   'C': [1,7,4,5,2]})

print('INPUT DATA FRAME\n',df)

   
def filter_dataframe(df):    
    df = df[(df['A']>5) & (df['B']<10)]
    return df

df_updated = filter_dataframe(df)

print('Filtered Dataframe\n',df_updated)
# Out:
# INPUT DATA FRAME
#     A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2
# Filtered Dataframe
#     A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# ####  NOTE: As per the condition given, ROW 2 also satisfies the condition and hence the result shows the second row.

# %% [markdown]
# ## Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
import pandas as pd

df = pd.DataFrame({'values':[10,20,30,40,50]})

df
# Out:
#    values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def mean_values(df):
    mean = df['values'].mean()  # Calculating the mean of the column Values
    return mean 

def median_values(df):
    median = df['values'].median()  # Calculating the median of the column Values
    return median 

def SD_values(df):
    SD = df['values'].std()  # Calculating the standard deviation of the column Values
    return SD 
    

print(f'The mean of values column of Data Frame is :  {mean_values(df)}' )
print(f'The median of values column of Data Frame is :  {median_values(df)}' )
print(f'The Standard Deviation of values column of Data Frame is :  {SD_values(df)}' )
# Out:
# The mean of values column of Data Frame is :  30.0
# The median of values column of Data Frame is :  30.0
# The Standard Deviation of values column of Data Frame is :  15.811388300841896

# %% [markdown]
# ## Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import pandas as pd

df = pd.read_csv('sales_data_sample.csv')

df
# Out:
#     PRODUCTLINE    SALES         ORDERDATE
# 0   Motorcycles  2871.00    2/24/2003 0:00
# 1   Motorcycles  2765.90  05-07-2003 00:00
# 2   Motorcycles  3884.34  07-01-2003 00:00
# 3   Motorcycles  3746.70    8/25/2003 0:00
# 4   Motorcycles  5205.27  10-10-2003 00:00
# 5   Motorcycles  3479.76   10/28/2003 0:00
# 6   Motorcycles  2497.77  11-11-2003 00:00
# 7   Motorcycles  5512.32   11/18/2003 0:00
# 8   Motorcycles  2168.54  12-01-2003 00:00
# 9   Motorcycles  4708.44    1/15/2004 0:00
# 10  Motorcycles  3965.66    2/20/2004 0:00
# 11  Motorcycles  2333.12  04-05-2004 00:00
# 12  Motorcycles  3188.64    5/18/2004 0:00
# 13  Motorcycles  3676.76    6/28/2004 0:00
# 14  Motorcycles  4177.35    7/23/2004 0:00
# 15  Motorcycles  4099.68    8/27/2004 0:00
# 16  Motorcycles  2597.39    9/30/2004 0:00
# 17  Motorcycles  4394.38   10/15/2004 0:00
# 18  Motorcycles  4358.04  11-02-2004 00:00

# %%
# calculating simple moving average of sales column(Simple moving Average SMA7)
# using .rolling(window).mean() ,
# with window size = 7

def moving_average(df):
    df['Moving Average'] = df['SALES'].rolling(7,min_periods=1).mean()
    return df

df_updated = moving_average(df)

df_updated
# Out:
#     PRODUCTLINE    SALES         ORDERDATE  Moving Average
# 0   Motorcycles  2871.00    2/24/2003 0:00     2871.000000
# 1   Motorcycles  2765.90  05-07-2003 00:00     2818.450000
# 2   Motorcycles  3884.34  07-01-2003 00:00     3173.746667
# 3   Motorcycles  3746.70    8/25/2003 0:00     3316.985000
# 4   Motorcycles  5205.27  10-10-2003 00:00     3694.642000
# 5   Motorcycles  3479.76   10/28/2003 0:00     3658.828333
# 6   Motorcycles  2497.77  11-11-2003 00:00     3492.962857
# 7   Motorcycles  5512.32   11/18/2003 0:00     3870.294286
# 8   Motorcycles  2168.54  12-01-2003 00:00     3784.957143
# 9   Motorcycles  4708.44    1/15/2004 0:00     3902.685714
# 10  Motorcycles  3965.66    2/20/2004 0:00     3933.965714
# 11  Motorcycles  2333.12  04-05-2004 00:00     3523.658571
# 12  Motorcycles  3188.64    5/18/2004 0:00     3482.070000
# 13  Motorcycles  3676.76    6/28/2004 0:00     3650.497143
# 14  Motorcycles  4177.35    7/23/2004 0:00     3459.787143
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.DataFrame({'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']})

df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
# Function to get the weekdays name

def get_weekday(df):
    df['Date'] = pd.to_datetime(df['Date']) # Convert the date into datetime data type
    df['Weekdays'] = df['Date'].dt.day_name()
    return df

df_updated = get_weekday(df)

df_updated
# Out:
#         Date   Weekdays
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# ## Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
import pandas as pd

data = {'Date':pd.date_range(start='1/1/2022', end='1/31/2023')}

df = pd.DataFrame(data)

df
# Out:
#           Date
# 0   2022-01-01
# 1   2022-01-02
# 2   2022-01-03
# 3   2022-01-04
# 4   2022-01-05
# ..         ...
# 391 2023-01-27
# 392 2023-01-28
# 393 2023-01-29
# 394 2023-01-30
# 395 2023-01-31
#
# [396 rows x 1 columns]

# %%
def get_date(df):
    
    df = df[df['Date'].between("2023-01-01", "2023-01-31")]
    
    return df

df_updated = get_date(df)

df_updated
# Out:
#           Date
# 365 2023-01-01
# 366 2023-01-02
# 367 2023-01-03
# 368 2023-01-04
# 369 2023-01-05
# 370 2023-01-06
# 371 2023-01-07
# 372 2023-01-08
# 373 2023-01-09
# 374 2023-01-10
# 375 2023-01-11
# 376 2023-01-12
# 377 2023-01-13
# 378 2023-01-14
# 379 2023-01-15
# 380 2023-01-16
# 381 2023-01-17
# 382 2023-01-18
# 383 2023-01-19
# 384 2023-01-20
# 385 2023-01-21
# 386 2023-01-22
# 387 2023-01-23
# 388 2023-01-24
# 389 2023-01-25
# 390 2023-01-26
# 391 2023-01-27
# 392 2023-01-28
# 393 2023-01-29
# 394 2023-01-30
# 395 2023-01-31

# %% [markdown]
# ## Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# **The First and foremost necessary library that needs to be imported is to use basic function in pandas is**

# %%
import pandas as pd

# %% [markdown]
# ### Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data. The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
