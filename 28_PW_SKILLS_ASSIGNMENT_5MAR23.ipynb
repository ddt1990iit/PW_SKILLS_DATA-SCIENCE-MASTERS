# %% [markdown]
# # ASSIGNMENT_5TH MAR_2023_PWSKIILLS

# %% [markdown]
# ## Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# **Bokeh** is a Python library which is used for data visualization through high-performance interactive charts and plots. It creates its plots using HTML and JavaScript languages. The output of the bokeh library can be generated on several platforms such as browser, HTML, server, and notebook. It is also possible to create the bokeh plots in Django and flask applications.
#
# The **bokeh** library provides two visualization interfaces to the users:
#
# * **models:** it is a low-level interface which provides high flexibility to the application developers.
# * **plotting:** it is a high-level interface which is used for creating visual glyphs.

# %%
# Example code showing the plot method in Bokeh

# Import the bokeh.plotting module 
from bokeh.plotting import figure as fig  
from bokeh.plotting import output_notebook as ON  
from bokeh.plotting import show  
import matplotlib.pyplot as plt

   
# output to the notebook  
ON()  
    
# creating figure  
plot1 = fig(x_axis_label="Data1",y_axis_label="Data2",plot_width = 500, plot_height = 500, title = "Scatter Plot")  
    
# Plotting a scatter plot through random numbers
plot1.circle([1, 2, 3, 4, 5, 6], [2, 1, 6, 8, 0],   
         size = 12, color = "green")  
    
# show the results  
show(plot1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="61008679-402f-400b-84fe-d9bfcc30b7a1" data-root-id="1003"></div>

# %% [markdown]
# ## Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# **Glyps:** Any plot is usually made up of one or many geometrical shapes such as line, circle, rectangle, etc. These shapes have visual information about the corresponding set of data. In Bokeh terminology, these geometrical shapes are called gylphs. Bokeh plots constructed using bokeh.plotting interface use a default set of tools and styles. However, it is possible to customize the styles using available plotting tools.
#
# ### Types of Plots
# ### Different types of plots created using glyphs are as given below −
#
# **Line plot**
#
# This type of plot is useful for visualizing the movements of points along the x-and y-axes in the form of a line. It is used to perform time series analytics.
#
# **Bar plot**
#
# This is typically useful for indicating the count of each category of a particular column or field in your dataset.
#
# **Patch plot**
#
# This plot indicates a region of points in a particular shade of color. This type of plot is used to distinguish different groups within the same dataset.
#
# **Scatter plot**
#
# This type of plot is used to visualize relationship between two variables and to indicate the strength of correlation between them.

# %%
# Exapmle code to explain plotting of glyphs 

# First import the dataset using seaborn library
import seaborn as sns

df = sns.load_dataset('iris')

display(df.head())

# output to the notebook  
ON()  

plot1 = fig(x_axis_label="sepal_length",y_axis_label="sepal_width",plot_width = 500, plot_height = 500, title = "Iris Plots")

plot1.circle(df['sepal_length'],df['sepal_width'],color='green')

show(plot1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1101">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5bdd49ce-8c49-4d7e-9999-67e19aceaf84" data-root-id="1102"></div>

# %%
# Plotting the Bar glyphs
# First import the dataset using seaborn library
import seaborn as sns

df = sns.load_dataset('tips')

display(df.head())

# output to the notebook  
ON()  

plot1 = fig(x_axis_label="size",y_axis_label="tips",plot_width = 500, plot_height = 500, title = "Bar Plots")

plot1.vbar(x=df['size'], width=0.5, bottom=0,
       top=df['tip'], color="firebrick")

show(plot1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1210">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="54335bd9-0f01-45de-8e21-ab0cbe8bb4b1" data-root-id="1211"></div>

# %% [markdown]
# ## Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %% [markdown]
# ##Adding annotations
# Bokeh includes several different types of annotations you can use to add supplemental information to your visualizations.
#
# 1. Customizing Title
# 2. Labeling the axes
# 3. Providing a legend to the glyphs graph

# %% [markdown]
# ### Here is an example code that shows the customizing of a Bokeh plot by modifying the axes, legend, and background and grid lines:

# %%
# Code showing thw customization of Grapgs in Bokeh

# Import the bokeh.plotting module 
from bokeh.plotting import figure as fig  
from bokeh.plotting import output_notebook as ON  
from bokeh.plotting import show  
import matplotlib.pyplot as plt
import numpy as np

  
# output to the notebook  
ON()  

# Plotting the sin wave curve
x = np.linspace(0,4*np.pi,100)
y = np.sin(x)

p = fig(width=1000, height=400)

# configure visual properties on a plot's title attribute
p.title.text = "Sine Curve"
p.title.align = "center"
p.title.text_color = "Red"
p.title.text_font_size = "20px"
p.title.background_fill_color = "cyan"

# Customizing the axes label

p.xaxis.axis_label = "X-Value in Radian"
p.yaxis.axis_label = "Y-Value"

# Creating a legends of the line glyphs
p.circle(x,y,color='orange',legend_label = 'sinx')
p.square(x,2*y,color='cyan',legend_label = '2sinx')
p.line(x,-y,color='black',legend_label = '-sinx',dash=[3,3])


show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1329">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6b5d4a29-64a0-45c5-854a-e1edaaacd25c" data-root-id="1330"></div>

# %% [markdown]
# ## Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?

# %% [markdown]
# **Bokeh** architecture has a decouple design in which objects such as plots and glyphs are created using Python and converted in JSON to be consumed by BokehJS client library.
#
# However, it is possible to keep the objects in python and in the browser in sync with one another with the help of Bokeh Server. It enables response to User Interface (UI) events generated in a browser with the full power of python. It also helps automatically push server-side updates to the widgets or plots in a browser.
#
# A **Bokeh** server uses Application code written in Python to create Bokeh Documents. Every new connection from a client browser results in the Bokeh server creating a new document, just for that session.
#
# ![image.png](data:image/png;base64,...)

# %%
# showing the implementation of Bokeh server

# Import the bokeh.plotting module 
from bokeh.plotting import figure as fig  
from bokeh.plotting import show  
import matplotlib.pyplot as plt
import numpy as np
from bokeh.io import curdoc
from bokeh.layouts import row ,column
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider,TextInput


N=200

# Plotting the sin wave curve
x = np.linspace(0,4*np.pi,N)
y = np.sin(x)

source = ColumnDataSource(data = dict(x=x,y=y))

p = fig(plot_height = 400,plot_width =400,title='sine Wave')


# Creating a legends of the line glyphs
p.circle('x','y',source = source)
freq = Slider(title = 'frequency',value=1.0,start = 0.1,end=5.1,step=0.1)

# configure visual properties on a plot's title attribute
p.title.align = "center"
p.title.text_color = "Red"
p.title.text_font_size = "20px"
p.title.background_fill_color = "cyan"

# Customizing the axes label

p.xaxis.axis_label = "X-Value in Radian"
p.yaxis.axis_label = "Y-Value"

def update_data(attrname,old,new):
  a=1
  b=0
  w=0
  k=freq.value
  x=np.linspace(0,4*np.pi,N)
  y= a*np.sin(k*x+w)+b
  source.data =dict(x=x,y=y)
freq.on_change('value',update_data)
curdoc().add_root(row(freq,p,width=500))
curdoc().title = 'Sliders'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %%
# embeded a Bokeh plot into a web page or dashboard using Flask app

# Import the bokeh.plotting module 
from bokeh.plotting import figure as fig  
from bokeh.plotting import show  
import matplotlib.pyplot as plt
import numpy as np
from bokeh.io import curdoc
from bokeh.layouts import row ,column
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider,TextInput
from flask import Flask , render_template
from bokeh.embed import components

app = Flask(__name__)  # Defining a flask app


@app.route('/')
def Bokeh_Plot():
  N=200

  # Plotting the sin wave curve
  x = np.linspace(0,4*np.pi,N)
  y = np.sin(x)

  source = ColumnDataSource(data = dict(x=x,y=y))

  p = fig(plot_height = 400,plot_width =400,title='sine Wave')


  # Creating a legends of the line glyphs
  p.circle('x','y',source = source)
  freq = Slider(title = 'frequency',value=1.0,start = 0.1,end=5.1,step=0.1)

  # configure visual properties on a plot's title attribute
  p.title.align = "center"
  p.title.text_color = "Red"
  p.title.text_font_size = "20px"
  p.title.background_fill_color = "cyan"

  # Customizing the axes label

  p.xaxis.axis_label = "X-Value in Radian"
  p.yaxis.axis_label = "Y-Value"

  def update_data(attrname,old,new):
    a=1
    b=0
    w=0
    k=freq.value
    x=np.linspace(0,4*np.pi,N)
    y= a*np.sin(k*x+w)+b
    source.data =dict(x=x,y=y)
  freq.on_change('value',update_data)
  curdoc().add_root(row(freq,p,width=500))
  curdoc().title = 'Sliders'

  # Generate the HTML components
  script, div = components(p)

  # Render the template with the plot components
  return render_template('index.html', script=script, div=div)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
