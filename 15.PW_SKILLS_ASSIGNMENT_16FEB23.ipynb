# %% [markdown]
# # ASSIGNMENT_16thFEB_2023_PWSKIILLS

# %% [markdown]
# ## Q1. What is a database? Differentiate between SQL and NoSQL databases.

# %% [markdown]
# **A database** is an organized collection of structured information, or data, typically stored electronically in a computer system. A database is usually controlled by a database management system (DBMS). Together, the data and the DBMS, along with the applications that are associated with them, are referred to as a database system, often shortened to just database.
#
# Data within the most common types of databases in operation today is typically modeled in rows and columns in a series of tables to make processing and data querying efficient. The data can then be easily accessed, managed, modified, updated, controlled, and organized. Most databases use structured query language (SQL) for writing and querying data.

# %% [markdown]
# Difference between SQL and NoSQL databases![1.PNG](attachment:1.PNG)
#
# **ACID : (Atomicity, Consistency, Isolation and Durability)

# %% [markdown]
# ## Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.

# %% [markdown]
# **Data Definition Language(DDL)**: The Data Definition Language is made up of SQL commands that can be used to design the database structure. It simply handles database schema descriptions and is used to construct and modify the structure of database objects in the database.
#
# **DDL** refers to a set of SQL instructions for creating, modifying, and deleting database structures, but not data.
#
# A general user, who should be accessing the database through an application, should not execute these instructions. All DDL commands are auto-committed, which means they store all database changes permanently.

# %% [markdown]
# **CREATE**: This command is used to create the database or its objects (like table, index, function, views, store procedure, and triggers).
#
# #### Create Database Command
#
# ![Create%20Command.PNG](attachment:Create%20Command.PNG)

# %% [markdown]
# #### Create Table Command
# ![Create%20Command1.PNG](attachment:Create%20Command1.PNG)

# %% [markdown]
# **ALTER**: This is used to alter the structure of the database.
# ![alter%20command.PNG](attachment:alter%20command.PNG)

# %% [markdown]
# **DROP**: This command is used to delete objects from the database.
#
# ![Drop%20Table.PNG](attachment:Drop%20Table.PNG)

# %% [markdown]
# **TRUNCATE**: This is used to remove all records from a table, including all spaces allocated for the records are removed.
#
# ![truncate%20command.PNG](attachment:truncate%20command.PNG)

# %% [markdown]
# ## Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.

# %% [markdown]
# **DML** is short name of Data Manipulation Language which deals with data manipulation and includes most common SQL statements such SELECT, INSERT, UPDATE, DELETE, etc., and it is used to store, modify, retrieve, delete and update data in a database.
#
#
# **INSERT** - insert data into a table
# **UPDATE** - updates existing data within a table
#
# ![INSERT%20COMMAND.PNG](attachment:INSERT%20COMMAND.PNG)

# %% [markdown]
# **DELETE** - Delete all records from a database table

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root", password="mysql",database='pwskills')
print(mydb)

mycursor = mydb.cursor()

# Delete Command 

mycursor.execute("DELETE from student_details WHERE student_id = 4 ")

# %% [markdown]
# ## Q4. What is DQL? Explain SELECT with an example.

# %% [markdown]
# **DQL (Data Query Language):**
# DQL statements are used for performing queries on the data within schema objects. The purpose of the DQL Command is to get some schema relation based on the query passed to it. We can define DQL as follows it is a component of SQL statement that allows getting data from the database and imposing order upon it. It includes the SELECT statement. This command allows getting the data out of the database to perform operations with it. When a SELECT is fired against a table or tables the result is compiled into a further temporary table, which is displayed or perhaps received by the program i.e. a front-end.
#
# **SELECT :** It is used to retrieve data from the database.
# ![SELECT%20STATEMENT.PNG](attachment:SELECT%20STATEMENT.PNG)

# %% [markdown]
# ## Q5. Explain Primary Key and Foreign Key.

# %% [markdown]
# **A Primary key** is a unique column we set in a table to easily identify and locate data in queries. A table can have only one primary key.
# The primary key column has a unique value and doesn’t store repeating values. A Primary key can never take NULL values.
# For example, in the case of a student when identification needs to be done in the class, the roll number of the student plays the role of Primary key.
# Similarly, when we talk about employees in a company, the employee ID is functioning as the Primary key for identification.
#
#
# **A Foreign key** is beneficial when we connect two or more tables so that data from both can be put to use parallelly.
# A foreign key is a field or collection of fields in a table that refers to the Primary key of the other table. It is responsible for managing the relationship between the tables.
# The table which contains the foreign key is often called the child table, and the table whose primary key is being referred by the foreign key is called the Parent Table.

# %% [markdown]
# ## Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.

# %% [markdown]
# ![Create%20Command.PNG](attachment:Create%20Command.PNG)

# %% [markdown]
# **Cursor()** : The MySQLCursor class instantiates objects that can execute operations such as SQL statements. Cursor objects interact with the MySQL server using a MySQLConnection object. To create a cursor, use the cursor() method of a connection object.

# %% [markdown]
# **The execute()** method helps us to execute the query and return records according to the query.
# The syntax of the execute () function is:
#
# cursor.execute (query, args = None)
#
# Parameters :
# query: This should be a string type.
# Arguments: By default, the arguments are None because sometimes we can pass only a query like a SELECT query which fetches the records and does not require any values. So that’s the reason for the args=None by default. But if we want to pass the values in the case of the INSERT query, then the type of the arguments must be a tuple, list, or dict only.
#
# Returns:
# It will return the count of the numbers of rows affected during the query.

# %% [markdown]
# ## Q7. Give the order of execution of SQL clauses in an SQL query.

# %% [markdown]
# In the modern world, SQL query planners can do all sorts of tricks to make queries run more efficiently, but they must always reach the same final answer as a query that is executed per the standard SQL order of execution. This order is:

# %% [markdown]
# ![12.PNG](attachment:12.PNG)
